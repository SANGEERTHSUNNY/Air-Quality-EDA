# %% [markdown]
# ##INTRODUCTION TO EDA

# %% [markdown]
# Exploratory Data Analysis(EDA) is a process of examining the data, extracting insights of the data.Originally developed by American mathematician John Tukey in the 1970s, EDA techniques continue to be a widely used method in the data discovery process today.In statistics, EDA is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods.

# %% [markdown]
# ##LOAD DATA

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
print(df.to_string())
# Out:
#     Country           State                city                                                 place           lastupdate    Avg    Max    Min Pollutants
# 0     India  Andhra_Pradesh           Amaravati                        Secretariat, Amaravati - APPCB  21-12-2018 03:00:00   70.0  108.0   42.0      PM2.5
# 1     India  Andhra_Pradesh           Amaravati                        Secretariat, Amaravati - APPCB  21-12-2018 03:00:00   76.0  102.0   43.0       PM10
# 2     India  Andhra_Pradesh           Amaravati                        Secretariat, Amaravati - APPCB  21-12-2018 03:00:00   73.0  118.0   46.0        NO2
# 3     India  Andhra_Pradesh           Amaravati                        Secretariat, Amaravati - APPCB  21-12-2018 03:00:00    5.0    6.0    4.0        NH3
# 4     India  Andhra_Pradesh           Amaravati                        Secretariat, Amaravati - APPCB  21-12-2018 03:00:00   41.0  109.0    2.0        SO2
# ...

# %% [markdown]
# ##LOAD HEAD

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.head()
# Out:
#   Country           State       city                           place  \
# 0   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 1   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 2   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 3   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 4   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
#
#             lastupdate   Avg    Max   Min Pollutants
# 0  21-12-2018 03:00:00  70.0  108.0  42.0      PM2.5
# 1  21-12-2018 03:00:00  76.0  102.0  43.0       PM10
# 2  21-12-2018 03:00:00  73.0  118.0  46.0        NO2
# 3  21-12-2018 03:00:00   5.0    6.0   4.0        NH3
# 4  21-12-2018 03:00:00  41.0  109.0   2.0        SO2

# %% [markdown]
# ##LOAD TAIL

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.tail()
# Out:
#     Country        State      city                               place  \
# 819   India  West_Bengal  Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 820   India  West_Bengal  Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 821   India  West_Bengal  Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 822   India  West_Bengal  Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 823   India  West_Bengal  Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
#
#               lastupdate   Avg   Max   Min Pollutants
# 819  21-12-2018 03:00:00  49.0  83.0  14.0        NO2
# 820  21-12-2018 03:00:00   8.0  13.0   2.0        NH3
# 821  21-12-2018 03:00:00   5.0   8.0   2.0        SO2
# 822  21-12-2018 03:00:00  33.0  67.0  14.0         CO
# 823  21-12-2018 03:00:00  33.0  65.0   7.0      OZONE

# %% [markdown]
# ##LOAD COLUMNS

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.columns
# Out:
# Index(['Country', 'State', 'city', 'place', 'lastupdate', 'Avg', 'Max', 'Min',
#        'Pollutants'],
#       dtype='object')

# %% [markdown]
# ##LOAD DATATYPE

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.dtypes
# Out:
# Country        object
# State          object
# city           object
# place          object
# lastupdate     object
# Avg           float64
# Max           float64
# Min           float64
# Pollutants     object
# dtype: object

# %% [markdown]
# ##LOAD INFO

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     824 non-null    object
#  1   State       824 non-null    object
#  2   city        824 non-null    object
#  3   place       824 non-null    object
#  4   lastupdate  824 non-null    object
#  5   Avg         788 non-null    float64
#  6   Max         788 non-null    float64
#  7   Min         788 non-null    float64
#  8   Pollutants  824 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 58.1+ KB

# %% [markdown]
# ##LOAD DISCRIBE

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.describe()
# Out:
#               Avg         Max         Min
# count  788.000000  788.000000  788.000000
# mean    96.736041  149.675127   50.855330
# std    114.746642  150.264480   74.279885
# min      1.000000    1.000000    1.000000
# 25%     20.000000   35.000000    7.000000
# 50%     50.000000  103.000000   20.000000
# 75%    108.000000  180.250000   54.000000
# max    457.000000  500.000000  335.000000

# %% [markdown]
# ##LOAD GROUPBY

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.groupby
# Out:
# <bound method DataFrame.groupby of     Country           State       city                               place  \
# 0     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 1     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 2     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 3     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 4     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# ..      ...             ...        ...                                 ...
# 819   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 820   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 821   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 822   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 823   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
#
# ...

# %% [markdown]
# ## FILTER THE DATA

# %%
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
df[df['Min']==1].head()
# Out:
#     Country  State   city                                         place  \
# 53    India  Delhi  Delhi                          Alipur, Delhi - DPCC
# 103   India  Delhi  Delhi  Dr. Karni Singh Shooting Range, Delhi - DPCC
# 114   India  Delhi  Delhi                 IGI Airport (T3), Delhi - IMD
# 115   India  Delhi  Delhi                 IGI Airport (T3), Delhi - IMD
# 141   India  Delhi  Delhi        Jawaharlal Nehru Stadium, Delhi - DPCC
#
#               lastupdate    Avg    Max  Min Pollutants
# 53   21-12-2018 03:00:00   41.0   86.0  1.0      OZONE
# 103  21-12-2018 03:00:00  150.0  150.0  1.0      OZONE
# 114  21-12-2018 03:00:00    7.0   21.0  1.0         CO
# 115  21-12-2018 03:00:00    8.0   22.0  1.0      OZONE
# 141  21-12-2018 03:00:00   40.0  111.0  1.0      OZONE

# %% [markdown]
# ##BOXPLOT

# %%
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
df[['Max']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ## CORRELATION PLOT

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.corr()
# Out:
# <ipython-input-35-b25c9fa67518>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Avg       Max       Min
# Avg  1.000000  0.960141  0.933346
# Max  0.960141  1.000000  0.859276
# Min  0.933346  0.859276  1.000000

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=pd.read_excel('/content/AirQuality.xlsx')
sns.heatmap(df.corr())
# Out:
# <ipython-input-37-f1b31d335b68>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# ##LOAD MEAN

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.mean()
# Out:
# <ipython-input-38-0dba1920ece9>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Avg     96.736041
# Max    149.675127
# Min     50.855330
# dtype: float64

# %% [markdown]
# ##LOAD MEDIAN

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.median()
# Out:
# <ipython-input-40-4149984b4ca7>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Avg     50.0
# Max    103.0
# Min     20.0
# dtype: float64

# %% [markdown]
# ##LOAD MODE

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.mode()
# Out:
#    Country  State   city                                           place  \
# 0    India  Delhi  Delhi                    Adarsh Nagar, Jaipur - RSPCB
# 1      NaN    NaN    NaN                            Alipur, Delhi - DPCC
# 2      NaN    NaN    NaN  Anand Kala Kshetram, Rajamahendravaram - APPCB
# 3      NaN    NaN    NaN                       Anand Vihar, Delhi - DPCC
# 4      NaN    NaN    NaN             Asansol Court Area, Asansol - WBPCB
# ..     ...    ...    ...                                             ...
# 75     NaN    NaN    NaN                       Vivek Vihar, Delhi - DPCC
# 76     NaN    NaN    NaN              Ward-32 Bapupara, Siliguri - WBPCB
# 77     NaN    NaN    NaN                          Wazirpur, Delhi - DPCC
# 78     NaN    NaN    NaN                Yamunapuram, Bulandshahr - UPPCB
# 79     NaN    NaN    NaN                     Zoo Park, Hyderabad - TSPCB
#
#              lastupdate   Avg    Max  Min Pollutants
# ...

# %% [markdown]
# ##STANDARD DEVIATION

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.std()
# Out:
# <ipython-input-41-240b98ede882>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Avg    114.746642
# Max    150.264480
# Min     74.279885
# dtype: float64

# %% [markdown]
# ##SUM OF NULL VALUES OF EACH COLUMN

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.isnull().sum()
# Out:
# Country        0
# State          0
# city           0
# place          0
# lastupdate     0
# Avg           36
# Max           36
# Min           36
# Pollutants     0
# dtype: int64

# %% [markdown]
# ##SOME OF  DUPLICATE OF DATA

# %%
import pandas as pd
df = pd.read_excel('/content/AirQuality.xlsx')
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##CHECK FOR DUPLICATION

# %%
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
df.nunique()
# Out:
# Country         1
# State          17
# city           71
# place         132
# lastupdate      1
# Avg           249
# Max           287
# Min           181
# Pollutants      7
# dtype: int64

# %% [markdown]
# ##CALCULATE THE PERCENTAGE OF MISSING VALUES IN EACH COLUMN

# %%
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
(df.isnull().sum()/(len(df)))*100
# Out:
# Country       0.000000
# State         0.000000
# city          0.000000
# place         0.000000
# lastupdate    0.000000
# Avg           4.368932
# Max           4.368932
# Min           4.368932
# Pollutants    0.000000
# dtype: float64

# %% [markdown]
# ##COUNT UNIQUE OF MAX COLUMN

# %%
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
df['Max'].value_counts()
# Out:
# 500.0    34
# 121.0    10
# 3.0      10
# 29.0      9
# 102.0     9
#          ..
# 167.0     1
# 161.0     1
# 79.0      1
# 332.0     1
# 313.0     1
# Name: Max, Length: 287, dtype: int64

# %% [markdown]
# ##LOAD SUM

# %%
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
df.sum()
# Out:
# Country       IndiaIndiaIndiaIndiaIndiaIndiaIndiaIndiaIndiaI...
# State         Andhra_PradeshAndhra_PradeshAndhra_PradeshAndh...
# city          AmaravatiAmaravatiAmaravatiAmaravatiAmaravatiA...
# place         Secretariat, Amaravati - APPCBSecretariat, Ama...
# lastupdate    21-12-2018 03:00:0021-12-2018 03:00:0021-12-20...
# Avg                                                     76228.0
# Max                                                    117944.0
# Min                                                     40074.0
# Pollutants    PM2.5PM10NO2NH3SO2COOZONEPM2.5PM10NO2NH3SO2COO...
# dtype: object

# %% [markdown]
# ##LOAD COUNT

# %%
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
df.count()
# Out:
# Country       824
# State         824
# city          824
# place         824
# lastupdate    824
# Avg           788
# Max           788
# Min           788
# Pollutants    824
# dtype: int64

# %% [markdown]
# ##FILTERING DATA BASED ON CERTAIN COLUMNS

# %%
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
df.loc[(df['State']=='Andhra_Pradesh') & (df['Min']<34) & (df['Avg']==41)]
# Out:
#   Country           State       city                           place  \
# 4   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
#
#             lastupdate   Avg    Max  Min Pollutants
# 4  21-12-2018 03:00:00  41.0  109.0  2.0        SO2

# %%
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
df[df.Min>40|(df.Avg==10)]
# Out:
#     Country           State       city                               place  \
# 0     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 1     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 2     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 3     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 4     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# ..      ...             ...        ...                                 ...
# 819   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 820   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 821   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 822   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 823   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
#
#               lastupdate   Avg    Max   Min Pollutants
# ...

# %% [markdown]
# ####SELECTING 3 COLUMNS RANDOMLY

# %%
import numpy as np
import pandas as pd
df=pd.read_excel('/content/AirQuality.xlsx')
df4=df[['Country','city','State']]
df4
# Out:
#     Country       city           State
# 0     India  Amaravati  Andhra_Pradesh
# 1     India  Amaravati  Andhra_Pradesh
# 2     India  Amaravati  Andhra_Pradesh
# 3     India  Amaravati  Andhra_Pradesh
# 4     India  Amaravati  Andhra_Pradesh
# ..      ...        ...             ...
# 819   India   Siliguri     West_Bengal
# 820   India   Siliguri     West_Bengal
# 821   India   Siliguri     West_Bengal
# 822   India   Siliguri     West_Bengal
# 823   India   Siliguri     West_Bengal
#
# [824 rows x 3 columns]

# %% [markdown]
# ##DISTPLOT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/AirQuality.xlsx')
plt.figure(figsize=(6,3.2),dpi=150)
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=8)
sns.distplot(df['Max'])
plt.show()

# %% [markdown]
# ##HISTPLOT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/AirQuality.xlsx')
sns.histplot(df['Max'],palette='hls')
plt.show()

# %% [markdown]
# ##PIECHART

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/AirQuality.xlsx')
df.groupby(['State']).sum().plot( kind='pie', y='Avg',autopct='%1.0f%%')
plt.show()

# %% [markdown]
# ##BAR PLOT

# %%
import numpy as np
df=pd.read_excel('/content/AirQuality.xlsx')
df.plot.bar(x='city',y='Avg',rot=0);

# %% [markdown]
# ##SCATTER PLOT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/AirQuality.xlsx')
x=df['Max']
y=df['Min']
plt.scatter(x, y,cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# ##PAIRPLOT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/AirQuality.xlsx')
sns.pairplot(df)
plt.show()

# %% [markdown]
# ##CORRELATION HEATMAP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/AirQuality.xlsx')
sns.heatmap(df.corr(),annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ##HISTPLOT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/AirQuality.xlsx')
plt.figure(figsize=(9,6))
sns.histplot(df['Avg'],palette='Spectral',kde=True,binwidth=2)
plt.grid(axis='y',color='green',linestyle='--',linewidth=0.5)
plt.show()

# %% [markdown]
# ##LINE PLOT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel('/content/AirQuality.xlsx')
df4=df[['Avg','State','Min']]
sns.lineplot(x='Avg',y='Min',data=df4,color='green')
plt.show()
